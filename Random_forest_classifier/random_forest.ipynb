# %% [markdown]
# <a href="https://colab.research.google.com/github/akkshatk-92/100-Days-of-Machine-Leaning/blob/main/Random_forest_classifier/random_forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC

import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c2a837ff-a3dd-4045-9366-83be32f2cf3c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c2a837ff-a3dd-4045-9366-83be32f2cf3c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
for filename in uploaded.keys():
    df = pd.read_csv(io.BytesIO(uploaded[filename]))
    print(f"Successfully loaded '{filename}' into a DataFrame.")
    break


display(df.head())
# Out:
# Successfully loaded 'heart.csv' into a DataFrame.
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1   37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2   41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3   56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4   57    0   0       120   354    0  ...      1      0.6      2   0     2       1
#
# [5 rows x 14 columns]

# %%
df.shape
# Out:
# (303, 14)

# %%
X=df.iloc[:,0:-1]
y=df.iloc[:,-1]

# %%
print(X.shape)
print(y.shape)
# Out:
# (303, 13)
# (303,)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (242, 13)
# (61, 13)

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9180327868852459

# %%
lg= LogisticRegression(max_iter=1000)
lg.fit(X_train,y_train)
y_pred=lg.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.8852459016393442

# %%
sv = SVC()
sv.fit(X_train, y_train)
y_pred = sv.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6721311475409836

# %% [markdown]
# **Hypermater Tuning in RandomForestClssifier**

# %%
rf=RandomForestClassifier(max_samples=0.75,random_state=42)
rf.fit(X_train,y_train)
y_pred=rf.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.8688524590163934

# %%
from sklearn.model_selection import cross_val_score
np.mean(cross_val_score(RandomForestClassifier(max_samples=0.75),X,y,cv=10,scoring='accuracy'))
# Out:
# np.float64(0.8381720430107527)

# %% [markdown]
# **Applying GridSearchCV**

# %%
from sklearn.model_selection import GridSearchCV
model_params = {
    'n_estimators': [10, 50, 100, 120],
    'max_depth': [2,8,None],
    'max_features':[0.2,0.6,1.0],
    'max_samples':[0.5,0.75,1.0]
}
print(model_params)
# Out:
# {'n_estimators': [10, 50, 100, 120], 'max_depth': [2, 8, None], 'max_features': [0.2, 0.6, 1.0], 'max_samples': [0.5, 0.75, 1.0]}

# %%
gs= GridSearchCV(RandomForestClassifier(),model_params,cv=5)
gs.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [2, 8, None],
#                          'max_features': [0.2, 0.6, 1.0],
#                          'max_samples': [0.5, 0.75, 1.0],
#                          'n_estimators': [10, 50, 100, 120]})

# %%
gs.best_estimator_
# Out:
# RandomForestClassifier(max_depth=2, max_features=0.2, max_samples=0.5)

# %%
accuracy_score(y_test,gs.predict(X_test))
# Out:
# 0.9016393442622951

# %%
gs.best_score_
# Out:
# np.float64(0.8414754098360657)
